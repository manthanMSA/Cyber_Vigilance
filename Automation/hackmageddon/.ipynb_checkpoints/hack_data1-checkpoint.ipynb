# %%
import numpy as np
import pandas as pd
#import matplotlib as mpl
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (13, 7)
plt.rcParams['font.size'] = 15.0
#plt.rcParams.update({'font.size': 28})
import seaborn as sns
from collections import Counter
import nltk
from nltk.corpus import brown
import re
import os
import codecs
from sklearn import feature_extraction

# %%
hack = pd.read_csv('scrappedData2.csv')

# %%
hack
# Out:
#                     Attack Attack_class        Author Country  \
# 0                  Malware           CC             ?      >1
# 1                  Malware           CC         Conti      US
# 2                  Malware           CC  Mount Locker      US
# 3                  Malware           CC  Mount Locker      UK
# 4                  Malware           CE      Thallium      KR
# ...                    ...          ...           ...     ...
# 2505               Unknown           CC             ?      US
# 2506  Fake Social Accounts          NaN             ?      CN
# 2507      Account Takeover           CC             ?      SG
# 2508               Malware           CC             ?      US
# 2509               Unknown           CC             ?      UK
#
#                                             Description  \
# 0     Security researchers discover using the BSSID ...
# 1     Gastroenterology Consultants Ltd have some dat...
# 2     Dassault Falcon Jet discloses a data breach af...
# 3     Amey Plc, the British company providing infras...
# 4     Researchers from ESTsecurity reveal that North...
# ...                                                 ...
# 2505  Donnelley & Sons, a vendor of NJ Office of Inf...
# 2506  U.S. online store PulseTV discloses a large-sc...
# 2507  Singapore police warns of a spate of phishing ...
# 2508  New Leaf, Inc., a non-profit provider of servi...
# 2509  The Gloucester City Council suffers a cyber at...
#
#                                                  Target  \
# 0                                      Multiple targets
# 1                      Gastroenterology Consultants Ltd
# 2                                   Dassault Falcon Jet
# 3                                              Amey PLC
# 4     Users of a private stock investment messenger ...
# ...                                                 ...
# 2505                                   Donnelley & Sons
# 2506                                            PulseTV
# 2507                                     OCBC Customers
# 2508                                     New Leaf, Inc.
# 2509                            Gloucester City Council
#
#                                          Target_class  Year         dat
# 0                               Y Multiple Industries  2020  22/12/2020
# 1           Q Human health and social work activities  2020  23/12/2020
# 2                                     C Manufacturing  2020  31/12/2020
# 3     N Administrative and support service activities  2021  01/01/2021
# 4                               Y Multiple Industries  2021  03/01/2021
# ...                                               ...   ...         ...
# 2505           Professional, scientific and technical  2021  29/12/2021
# 2506                                       Individual  2021  30/12/2021
# 2507                            Finance and insurance  2021  30/12/2021
# 2508                     Human health and social work  2021  30/12/2021
# 2509        Public admin and defence, social security  2021  31/12/2021
#
# [2510 rows x 9 columns]

# %%
hack.shape
# Out:
# (9107, 8)

# %%
hack.isnull().sum()
# Out:
# Attack_Type     0
# Attack_class    0
# Country         0
# Description     0
# Organization    0
# Sector          0
# Year            0
# dat             0
# dtype: int64

# %%
hack
# Out:
#      Attack_Type     Attack_class Country  \
# 0        Malware      Cyber Crime      RU
# 1        Malware      Cyber Crime      US
# 2        Malware      Cyber Crime      US
# 3        Malware      Cyber Crime      UK
# 4        Malware  Cyber Espionage      KR
# ...          ...              ...     ...
# 9102     Unknown      Cyber Crime      US
# 9103        DDoS       Hacktivism      GB
# 9104  Ransomware      Cyber Crime      RU
# 9105  Ransomware      Cyber Crime      AU
# 9106     Unknown      Cyber Crime      US
#
#                                             Description  \
# 0     Security researchers discover using the BSSID ...
# 1     Gastroenterology Consultants Ltd have some dat...
# 2     Dassault Falcon Jet discloses a data breach af...
# 3     Amey Plc, the British company providing infras...
# 4     Researchers from ESTsecurity reveal that North...
# ...                                                 ...
# 9102  A threat actor identified as ‘wangfei198609020...
# 9103  Anonymous Sudan, a Russia-affiliated hacktivis...
# 9104  Researchers from Border0 reveal the details of...
# 9105  Quantum Radiology is hit with a ransomware att...
# 9106  CarePro Health Services files a notice of data...
#
#                                            Organization  \
# 0                                      Multiple targets
# 1                      Gastroenterology Consultants Ltd
# 2                                   Dassault Falcon Jet
# 3                                              Amey PLC
# 4     Users of a private stock investment messenger ...
# ...                                                 ...
# 9102     Government Employees Insurance Company (GEICO)
# 9103                    London Internet Exchange (LINX)
# 9104                             Multiple organizations
# 9105                                  Quantum Radiology
# 9106                            CarePro Health Services
#
#                                              Sector  Year         dat
# 0                               Multiple Industries  2020  22-12-2020
# 1           Human health and social work activities  2020  23-12-2020
# 2                                     Manufacturing  2020  31-12-2020
# 3     Administrative and support service activities  2021  01-01-2021
# 4                               Multiple Industries  2021  03-01-2021
# ...                                             ...   ...         ...
# 9102                          Finance and insurance  2024  15-01-2024
# 9103                  Information and communication  2024  15-01-2024
# 9104                            Multiple Industries  2024  15-01-2024
# 9105                   Human health and social work  2024  15-01-2024
# 9106                   Human health and social work  2024  15-01-2024
#
# [9107 rows x 8 columns]

# %%
# hack.drop('Unnamed: 0', axis=1, inplace=True)

# %%
hack
# Out:
#      Attack_Type     Attack_class Country  \
# 0        Malware      Cyber Crime      RU
# 1        Malware      Cyber Crime      US
# 2        Malware      Cyber Crime      US
# 3        Malware      Cyber Crime      UK
# 4        Malware  Cyber Espionage      KR
# ...          ...              ...     ...
# 9102     Unknown      Cyber Crime      US
# 9103        DDoS       Hacktivism      GB
# 9104  Ransomware      Cyber Crime      RU
# 9105  Ransomware      Cyber Crime      AU
# 9106     Unknown      Cyber Crime      US
#
#                                             Description  \
# 0     Security researchers discover using the BSSID ...
# 1     Gastroenterology Consultants Ltd have some dat...
# 2     Dassault Falcon Jet discloses a data breach af...
# 3     Amey Plc, the British company providing infras...
# 4     Researchers from ESTsecurity reveal that North...
# ...                                                 ...
# 9102  A threat actor identified as ‘wangfei198609020...
# 9103  Anonymous Sudan, a Russia-affiliated hacktivis...
# 9104  Researchers from Border0 reveal the details of...
# 9105  Quantum Radiology is hit with a ransomware att...
# 9106  CarePro Health Services files a notice of data...
#
#                                            Organization  \
# 0                                      Multiple targets
# 1                      Gastroenterology Consultants Ltd
# 2                                   Dassault Falcon Jet
# 3                                              Amey PLC
# 4     Users of a private stock investment messenger ...
# ...                                                 ...
# 9102     Government Employees Insurance Company (GEICO)
# 9103                    London Internet Exchange (LINX)
# 9104                             Multiple organizations
# 9105                                  Quantum Radiology
# 9106                            CarePro Health Services
#
#                                              Sector  Year         dat
# 0                               Multiple Industries  2021  22-12-2020
# 1           Human health and social work activities  2021  23-12-2020
# 2                                     Manufacturing  2021  31-12-2020
# 3     Administrative and support service activities  2021  01-01-2021
# 4                               Multiple Industries  2021  03-01-2021
# ...                                             ...   ...         ...
# 9102                          Finance and insurance  2024  15-01-2024
# 9103                  Information and communication  2024  15-01-2024
# 9104                            Multiple Industries  2024  15-01-2024
# 9105                   Human health and social work  2024  15-01-2024
# 9106                   Human health and social work  2024  15-01-2024
#
# [9107 rows x 8 columns]

# %%
hack.to_csv("ndata.csv")

# %%
hack['Attack_Type'].value_counts()
# Out:
# Attack_Type
# Malware                                                                              3536
# Unknown                                                                              2048
# Account Takeover                                                                     1200
# Targeted Attack                                                                       687
# DDoS                                                                                  319
# CVE-2023-34362 Vulnerability                                                          309
# Vulnerability                                                                         139
# Misconfiguration                                                                      115
# Coordinated Inauthentic Behavior                                                       88
# Malicious Script Injection                                                             64
# Scam                                                                                   52
# Business Email Compromise                                                              52
# CVE-2023-0669 Fortra GoAnywhere MFT Vulnerability                                      46
# Defacement                                                                             38
# Malvertising                                                                           31
# Multiple vulnerabilities                                                               31
# Fake Social Accounts                                                                   30
# CVE-2021-44228 Vulnerability                                                           27
# SQLi                                                                                   20
# Credential Stuffing                                                                    20
# Ransomware                                                                             19
# CVE-2021-26855, CVE-2021-26857, CVE-2021-26858, \n CVE-2021-27065 Vulnerabilities      18
# >1                                                                                     16
# CVE-2022-26134 Vulnerability                                                           13
# Fake Websites/Social Network accounts                                                  12
# CVE-2023-38831 Vulnerability                                                           11
# Brute-force                                                                            11
# Malicious Browser Extension                                                            10
# Fake Social/Web pages                                                                  10
# Fake News/Social Profiles                                                              10
# Malicious Spam                                                                         10
# CID (Coordinated Inauthentic Behavior)                                                  9
# Undisclosed vulnerability                                                               9
# Cloud misconfiguration                                                                  9
# Zoom bombing                                                                            7
# Crypto Scam                                                                             7
# Malicious spam                                                                          6
# CVE-2023-3519 Vulnerability                                                             6
# CVE-2021-40539 Vulnerability                                                            6
# CVE-2021-40444 Vulnerability                                                            6
# Flash loan                                                                              5
# Deepfake                                                                                5
# CVE-2021-34473,\nCVE-2021-34523,  \nCVE-2021-31207 vulnerabilities                      5
# Malicious script injection                                                              5
# Credential stuffing                                                                     5
# Crypto scam                                                                             5
# CVE-2023-2868 Vulnerability                                                             5
# Multiple Vulnerabilities                                                                5
# CVE-2021-26084 Vulnerability                                                            5
# Vulnerability                                                                           5
# Name: count, dtype: int64

# %%
hack['Attack_class'].fillna('CC', inplace=True)

# %%
hack['Country'].fillna('US',inplace=True)

# %%
hack['Attack'].fillna('Malware',inplace=True)
hack['Sector'].fillna('Multiple Industries',inplace=True)
hack['Organization'].fillna('Accenture',inplace=True)

# %%
hack.isnull().sum()
# Out:
# Attack          0
# Attack_class    0
# Author          0
# Country         0
# Description     0
# Organization    0
# Sector          0
# Year            0
# dat             0
# dtype: int64

# %%
hack
# Out:
#           Attack Attack_class                Author Country  \
# 0        Malware           CC                     ?      >1
# 1        Malware           CC                 Conti      US
# 2        Malware           CC          Mount Locker      US
# 3        Malware           CC          Mount Locker      UK
# 4        Malware           CE              Thallium      KR
# ...          ...          ...                   ...     ...
# 9840     Unknown  Cyber Crime  ‘wangfei19860902055’      US
# 9841        DDoS   Hacktivism       Anonymous Sudan      GB
# 9842  Ransomware  Cyber Crime                     ?      >1
# 9843  Ransomware  Cyber Crime                     ?      AU
# 9844     Unknown  Cyber Crime                     ?      US
#
#                                             Description  \
# 0     Security researchers discover using the BSSID ...
# 1     Gastroenterology Consultants Ltd have some dat...
# 2     Dassault Falcon Jet discloses a data breach af...
# 3     Amey Plc, the British company providing infras...
# 4     Researchers from ESTsecurity reveal that North...
# ...                                                 ...
# 9840  A threat actor identified as ‘wangfei198609020...
# 9841  Anonymous Sudan, a Russia-affiliated hacktivis...
# 9842  Researchers from Border0 reveal the details of...
# 9843  Quantum Radiology is hit with a ransomware att...
# 9844  CarePro Health Services files a notice of data...
#
#                                            Organization  \
# 0                                      Multiple targets
# 1                      Gastroenterology Consultants Ltd
# 2                                   Dassault Falcon Jet
# 3                                              Amey PLC
# 4     Users of a private stock investment messenger ...
# ...                                                 ...
# 9840     Government Employees Insurance Company (GEICO)
# 9841                    London Internet Exchange (LINX)
# 9842                             Multiple organizations
# 9843                                  Quantum Radiology
# 9844                            CarePro Health Services
#
#                                              Sector  Year         dat
# 0                               Multiple Industries  2020  22-12-2020
# 1           Human health and social work activities  2020  23-12-2020
# 2                                     Manufacturing  2020  31-12-2020
# 3     Administrative and support service activities  2021  01-01-2021
# 4                               Multiple Industries  2021  03-01-2021
# ...                                             ...   ...         ...
# 9840                          Finance and insurance  2024  15-01-2024
# 9841                  Information and communication  2024  15-01-2024
# 9842                            Multiple Industries  2024  15-01-2024
# 9843                   Human health and social work  2024  15-01-2024
# 9844                   Human health and social work  2024  15-01-2024
#
# [9845 rows x 9 columns]

# %%
hack
# Out:
#           Attack     Attack_class Country  \
# 0        Malware      Cyber Crime      RU
# 1        Malware      Cyber Crime      US
# 2        Malware      Cyber Crime      US
# 3        Malware      Cyber Crime      UK
# 4        Malware  Cyber Espionage      KR
# ...          ...              ...     ...
# 9840     Unknown      Cyber Crime      US
# 9841        DDoS       Hacktivism      GB
# 9842  Ransomware      Cyber Crime      RU
# 9843  Ransomware      Cyber Crime      AU
# 9844     Unknown      Cyber Crime      US
#
#                                             Description  \
# 0     Security researchers discover using the BSSID ...
# 1     Gastroenterology Consultants Ltd have some dat...
# 2     Dassault Falcon Jet discloses a data breach af...
# 3     Amey Plc, the British company providing infras...
# 4     Researchers from ESTsecurity reveal that North...
# ...                                                 ...
# 9840  A threat actor identified as ‘wangfei198609020...
# 9841  Anonymous Sudan, a Russia-affiliated hacktivis...
# 9842  Researchers from Border0 reveal the details of...
# 9843  Quantum Radiology is hit with a ransomware att...
# 9844  CarePro Health Services files a notice of data...
#
#                                            Organization  \
# 0                                      Multiple targets
# 1                      Gastroenterology Consultants Ltd
# 2                                   Dassault Falcon Jet
# 3                                              Amey PLC
# 4     Users of a private stock investment messenger ...
# ...                                                 ...
# 9840     Government Employees Insurance Company (GEICO)
# 9841                    London Internet Exchange (LINX)
# 9842                             Multiple organizations
# 9843                                  Quantum Radiology
# 9844                            CarePro Health Services
#
#                                              Sector  Year         dat
# 0                               Multiple Industries  2020  22-12-2020
# 1           Human health and social work activities  2020  23-12-2020
# 2                                     Manufacturing  2020  31-12-2020
# 3     Administrative and support service activities  2021  01-01-2021
# 4                               Multiple Industries  2021  03-01-2021
# ...                                             ...   ...         ...
# 9840                          Finance and insurance  2024  15-01-2024
# 9841                  Information and communication  2024  15-01-2024
# 9842                            Multiple Industries  2024  15-01-2024
# 9843                   Human health and social work  2024  15-01-2024
# 9844                   Human health and social work  2024  15-01-2024
#
# [9845 rows x 8 columns]

# %%
hack['Attack_class'] = hack['Attack_class'].replace(['H','CC','CE','CW'],['Hacktivism', 'Cyber Crime','Cyber Espionage','Cyber War'])

# %%
hack['Attack_class'] = hack['Attack_class'].replace(['Cyber Warfare','>1','CC/CE','CCC','CE?','Cyber  Crime'],['Cyber War', 'Cyber Crime','Cyber Espionage','Cyber Crime','Cyber Crime','Cyber Crime'])

# %%
hack['Attack_class'].value_counts()
# Out:
# Attack_class
# Cyber Crime        8128
# Cyber Espionage     968
# Hacktivism          504
# Cyber War           245
# Name: count, dtype: int64

# %%
hack['Author'].value_counts()
# Out:
# Author
# ?                                          5156
# Multiple threat actors                      201
# LockBit 3.0                                 151
# Clop AKA Lace Tempest, TA505 and, FIN11     129
# Clop AKA Lace Tempest, TA505 and FIN11      106
#                                            ...
# TA459                                         1
# TA412 AKA Zirconium                           1
# DEV-0530 AKA H0lyGh0st                        1
# Mantis                                        1
# ‘wangfei19860902055’                          1
# Name: count, Length: 2035, dtype: int64

# %%
hack.drop('Author', axis=1, inplace=True)

# %%
hack["Attack"].value_counts()
# Out:
# Attack
# Malware                                     3536
# Unknown                                     2048
# Account Takeover                            1200
# Targeted Attack                              687
# DDoS                                         319
#                                             ...
# CVE-2022-1364 Vulnerability                    1
# Zimbra, CVE-2018-6882                          1
# Multiple vulnerabilities and brute-force       1
# CVE-2022-24521 Vulnerability                   1
# CVE-2023-36025 Vulnerability                   1
# Name: count, Length: 641, dtype: int64

# %%
hack["Country"].value_counts()
# Out:
# Country
# US                                    3611
# RU                                    2315
# IT                                     302
# UK                                     213
# UA                                     183
#                                       ...
# VU                                       1
# BR\nCH\nDE\nIN\nIT\nMX\nSA\nTR\nUS       1
# AU\nMM\nPH\nTW\nJP                       1
# BR\nDE\nID\nIN\nUS                       1
# MV                                       1
# Name: count, Length: 353, dtype: int64

# %%
hack['Country'] = hack['Country'].replace(['>1'],['RU'])

# %%
hack["Country"].unique()
# Out:
# array(['RU', 'US', 'UK', 'KR', 'MX', 'CN', 'CA', 'FR', 'TW', 'BE', 'AU',
#        'IL', 'TH', 'NL', 'NZ', 'IN', 'NO', 'CO', 'PK', 'CZ', 'BR', 'OM',
#        'US, CA', 'US, DE, AT', 'IE', 'BD', 'ID', 'IT', 'HK', 'IR', 'SG',
#        'AR', 'ZA', 'JP', 'TR', 'CH', 'PH', 'MY', 'Multiple targets', 'SE',
#        'DE', 'LK', 'US/CA', 'PL', 'PT', 'DZ', 'EU', 'LT', 'MM', 'UA',
#        'FI', 'VN', 'AZ', 'AO', '–', 'EC', 'ES', 'NL/UK', 'CL', 'US, IL',
#        'RO', 'PS', 'GE', 'AT', '>', 'SK', 'MA', 'JO', 'FJ', 'EE', 'LU',
#        'DO', 'QA', 'PR', 'SA', 'UK/US', 'DK', 'KE', 'GR', 'BY', 'TW\nKR',
#        'UAE', 'BH', 'AU\nDE', 'SV', 'US\nCA', 'AG', 'TG', 'US\nIL', 'TN',
#        'IN\nAF', 'VE', 'PG', 'AU\nTR', 'NI', 'AF', 'SY', 'IT\nFR', 'CF',
#        'LY\nSY', 'TZ', 'UG', 'KY', 'KH', 'LA', 'EG', 'AL', 'KP', 'BG',
#        'INT', 'PS\nTR', 'AD', 'LB', 'RS\nBA', 'N.A', 'DE\nFR', 'SL', 'HR',
#        'US\nUK', 'AE', 'RU\nBY', 'SD', 'LY', 'IQ', 'VA', 'UA\nPL',
#        'TW\nHK\nPH', 'CR\nSV', 'GI', 'CR', 'TT', 'NR', 'PE', 'US\nEU',
#        'ZM', 'RU\nGE\nMN', 'GL', 'US\nUA', 'AT\nEE',
#        'US\nIN\nMiddle East', 'SG\nHK\nVN\nKH\nAU',
#        'AU\nRU\nPH\nBE\nVN\nMY\nKD\nAF', 'IT\nES',
#        'AF\nBT\nIN\nNP\nPK\nLK', 'KZ\n SY\n IT', 'UK\n IT\n ES',
#        'JP\n Western countries', 'PK\n AF\n MY', 'US\n Europe',
#        'UA\n UAE\n PK\n NP\n BT\n KE\n LK\n ID', 'FR\nDE\nPL\nTR', 'LV',
#        'BR\nPT', 'AF\nIN\nIT\nPL\nUS', 'US\nIL\nSA', 'CZ\nPL',
#        'UK\nBE\nNL\nDE\nPL\nPT\nNO\nSE\nCZ', 'GT', 'US\n>1',
#        'NZ\nIN\nPK\nUK', 'AF\nIN\nPK\nAE\nSA', 'AO\nNG\nPS', 'AF\nEU',
#        'MD', 'IT\nDE\nFR\nUK\nAU\nIN\nBR', 'ES\nMX', 'ID\nSA\nZA\nTH',
#        'ME', 'BO', 'AT\nAU\nDE\nES\nPL\nUS', 'CI\nCM\nMA\nSN\nTG',
#        'US\nCA\nJP', 'BA', 'AU\nCA\nUK\nUS',
#        'BR\nDE\nEG\nFR\nIN\nIT\nRU\nUS\nTR', 'DE\nFR\nIT\nUA\nUK',
#        'US\nCZ', 'US\nNZ', 'PY', 'BE\nNL', 'CL\nCO\nMX\nPE\nSV',
#        'HK\nSG\nTH\nCN\nJP', 'SA\nUAE\nSG', 'GH', 'TW\nJP',
#        'CA\nCN\nIN\nJP\nUK\nUS', 'IL\nUS', 'AT\nFR\nDE', 'HU',
#        'DE\nFR\nIT\nNL\nUK', 'UK\n>1', 'CZ\nES\nFR\nPT\nRO\nUK', 'CN\nTW',
#        'CN\nIN\nMY\nTW\nTH\nPK\nUA', 'UY', 'VU',
#        'BR\nCH\nDE\nIN\nIT\nMX\nSA\nTR\nUS', 'AU\nMM\nPH\nTW\nJP',
#        'BR\nDE\nID\nIN\nUS', 'GP', 'KW', 'FR\nUK\nUS', 'BE\nFR\nLU',
#        'HK\nIL\nZA', 'AM\nAZ\nEG\nIQ\nIL\nOM\nQA\nTJ\nUAE',
#        'BY\nRU\nUA\nMD', 'BB', 'IN\nIT\nMX\nSG\nKZ\nRU',
#        'JP\nUAE\nUS\nVN', 'KZ', 'ES\nPT', 'CU', 'RS',
#        'BA\nID\nKH\nMY\nPH\nVN', 'PE\nPH\nTH', 'KR\nUS',
#        'AT\nKW\nPL\nUS\nTR', 'ES\nJP\nPL\nUK\nUS', 'JM',
#        'ES\nFI\nNL\nNO\nPL\nPT\nUK\nUS', 'ID\nTH\nTW', 'NP', 'PA',
#        'PL\nUA', 'DE\nUS', 'TO', 'iT', 'AF\nBT\nMM\nNP\nLK',
#        'DE\nDK\nEE\nES\nIT\nFR\nHU\nNL\nNO\nPL\nSE',
#        'AU\nCA\nFR\nDE\nES\nIT\nPL\nPT\nSE\nNL\nUS', 'AM',
#        'CN\nHK\nID\nJP\nMY\nMM\nPH\nSG\nTH\nTW', 'BR\nCN\nJP',
#        'HU\nIT\nUS', 'CO\nEC', 'TW\nUA', 'NG', 'AU\nDE\nDK\nIE\nNL',
#        'VN\nTH\nID', 'IN\nPK', 'MN\nPG\nGH\nZW\nNG',
#        'CN\nHK\nKR\nMY\nSG\nTW\nEU', 'BR\nFR\nTW', 'IN\nIT\nPL\nUA',
#        'AU\nDE\nFR\nIT\nNZ\nUS', 'AU\nUK', 'CL\nMX\nPE\nPT', 'CZ\nSK',
#        'AU\nES\nFR\nUK\nPL\n>1', 'CA\nFR\nIT\nUS', 'EU\nJP\nKR\nUS',
#        'EU\nRU', 'IT\nMY\nKZ', 'CZ\nES\nFR\nPL\nPT\nEU',
#        'AU\nDE\nDK\nIE\nJP\nKR\nUK\nUS\nZA', 'CY', 'UK\nIE', 'JP\nKR\nES',
#        'FR\nIT', 'AR\nBD\nES\nGR\nIN\nLB\nMX\nPK\nTO\nUS', 'AU\nPL',
#        'EC\nES\nCL\nCO', 'EU\nUS', 'JP\nTW', 'TJ', 'NP\nZA',
#        'CA\nBR\nKR\nUS', 'US\nIN\nTR', 'FJ\nPH\nTW\nTH',
#        'BD\nCN\nIN\nLK\nPK', 'BH\nFR\nIL', 'IN\nTB', 'HN\nGT', 'BF\nTG',
#        'CN\nHK\nJP\nPH\nSG\nTW', 'UK\nUS', 'PK\nTR', 'AU\nCA\nUS\nZA',
#        'AF\nKZ', 'CN\nPK', 'AU\nFR\nIN\nSG\nUK', 'DK\nNO\nSE',
#        'MX\nPE\nPT', 'BE\nBN\nID\nTH\nVN', 'AR\nBR\nGT\nMX\nPA\nUY\nVE',
#        'AU\nBR\nEE\nPE\nGB\nUS', 'UZ', 'GB', 'JP\nUS\nVN', 'ML', 'IN\nUS',
#        'AT\nCH\nDE\nGB\nUS', 'IE\nUS', 'CZ\nHU\nFR\nGB\nSE\nSK\nUA',
#        'CA\nUS', 'SG\nUS', 'MT',
#        'AU\nAT\nCH\nCN\nFR\nGB\nID\nIT\nJP\nPH\nPL\nSG\nUA\nUS', 'HK\nTR',
#        'GY\nKH\nIN\nLY\nML\nPK\nSR\nTH\nZA', 'VC', 'RU\nSR', 'CL\nMX',
#        'IL\nIN', 'BG\nCN\nVN', 'DE\nES\nKR\nFR\nPT\nUS', 'US\nTW',
#        'HK\n>1', 'US\nGB',
#        'AU\nBR\nCD\nDE\nDK\nES\nHK\nHU\nLT\nNL\nPL\nPT\nSG\nUA\nUS\nYE',
#        'DE\nFR\nUA', 'AU\nGB\nJP\nUS\nTW', 'DE\nMY\nPH\nTW\nUS\nZA',
#        'GB\nUS', 'KR\nTH', 'AU\nUS\nEU', 'AU\nBE\nPL',
#        'CA\nCH\nDE\nDZ\nFR\nMG\nSE\nSG\nTN\nUS\nVN', 'BR\nIL\nUAE', 'U.S',
#        'CN\nDE\nJP\nHK\nSG\nUS', 'BR\nMX', 'BM', 'BE\nCA\nES\nIT\nPT\nUS',
#        'MG', 'Us', 'HK\nSG\nTW', 'GY', 'TW\nUS\nVN', 'KZ\nUZ\nPK\nVN\n>1',
#        'DE\nGB\nIN\nIR\nJP\nRO\nRU\nSE\nUS', 'BR\nRO\nRU\nSA\nVN\n>1',
#        'IN\nUK\nUS', 'MX\nES', 'AZ\nKG\nTJ\nUZ',
#        'IQ\nIL\nJO\nKW\nOM\nSA\nUAE\nUS', 'AZ\nSA\nYE', 'JP\nUS',
#        'AR\nBO\nBR\nCL\nCO\nCU\nEC\nMX\nPY\nPE\nUY\nVE', 'GB\nPT',
#        'BY\nRU', 'AZ\nIT\nGR\nRO', 'U.S.', 'MD\nTN',
#        'CL\nDE\nHK\nPL\nUA\nUS\nVN',
#        'CN\nDE\nFR\nGB\nHK\nIE\nJP\nRU\nSG\nUS', 'DE\nFR\nIL\nUS', 'SI',
#        'BR\nUS\nZA', 'ID\nSG\nMY\nTH\nVN', 'KR\nUZ',
#        'CO\nEG\nID\nIN\nKE\nMX\nNG\nPE\nPH\nSG\nTH\nVN', 'AU\nNZ',
#        'KR\nN/A', 'DE\nUA\nUS', 'TH\n>1',
#        'AU\nAZ\nBE\nDE\nHU\nIT\nKZ\nLT\nPL\nRO\nSA\nTR\nUA', 'LS', 'SC',
#        'CO\nMX\nVN', 'AU\nBR\nCN\nID\nKR\nPH\nTH', 'JP\n>1', 'EG\nSD\nTZ',
#        'DE\nFR\nNL\nRS\nRU\nUS\nMK', 'AR\nAU\nBR\nDE\nES\nGB\nMX\nUS',
#        'UA\n>1', 'MV'], dtype=object)

# %%
hack['Sector'].value_counts()
# Out:
# Sector
# Multiple Industries                                                    2035
# Human health and social work                                            946
# Individual                                                              927
# Public admin and defence, social security                               803
# Professional, scientific and technical                                  609
# Education                                                               595
# Finance and insurance                                                   555
# Manufacturing                                                           348
# Fintech                                                                 337
# Information and communication                                           299
# Unknown                                                                 250
# Human health and social work activities                                 224
# Public administration and defence, compulsory social security           220
# Wholesale and retail                                                    201
# Transportation and storage                                              167
# Arts entertainment, recreation                                          166
# Administration and support service                                      156
# Professional scientific and technical activities                        135
# Accommodation and food service                                          126
# Other service activities                                                125
# Electricity, gas steam, air conditioning                                114
# Financial and insurance activities                                      108
# Administrative and support service activities                            68
# Arts entertainment and recreation                                        59
# Wholesale and retail trade                                               50
# Water supply, waste mgmt, remediation                                    45
# Real estate                                                              37
# Mining and quarrying                                                     34
# Extraterritorial orgs and bodies                                         27
# Accommodation and food service activities                                27
# Electricity gas steam and air conditioning supply                        21
# Activities of extraterritorial organizations and bodies                  10
# Real estate activities                                                    9
# Water supply, sewerage waste management, and remediation activities       5
# Information and Communication                                             3
# Human health and social work activities                                   1
# man health and social work                                                1
# known                                                                     1
# ts entertainment, recreation                                              1
# Name: count, dtype: int64

# %%
(hack['Description']=="?").sum()
# Out:
# 0

# %%
hack['Year'].value_counts()
# Out:
# Year
# 2023    3827
# 2022    2851
# 2021    2325
# 2024     104
# Name: count, dtype: int64

# %%
hack['Year'] = hack['Year'].replace(['3021','2020','3022'],['2021', '2021','2022'])

# %%
hack[hack['Year']=='3021']
# Out:
# Empty DataFrame
# Columns: [Attack_Type, Attack_class, Country, Description, Organization, Sector, Year, dat]
# Index: []

# %%
hack['Author']= hack['Author'].str.replace('Unknown','Anonymous')
hack['Attack']= hack['Attack'].str.replace('Unknown','Anonymous')

# %%
hack.columns = hack.columns.str.replace('dat','Date')

# %%
hack['Attack_class'] = hack['Attack_class'].replace(['H','CC','CE','CW'],['Hacktivism', 'Cyber Crime','Cyber Espionage','Cyber War'])

# %%
hack['Attack_class'] = hack['Attack_class'].replace(['H,','CC,CE','CC,','IN','JP','US','Industry: Telco','CW'],['Hacktivism', 'Cyber Crime','Cyber Crime','Cyber Espionage','Cyber Espionage','Cyber Espionage','Cyber Espionage','Cyber Espionage'])

# %%
hack['Attack']=[i.replace('?','') for i in hack['Attack']]
hack['Attack']=[i.replace(',\r','') for i in hack['Attack']]

# %%
hack.isnull().sum()
# Out:
# Unnamed: 0         1
# Attack             0
# Attack_class       0
# Author             0
# Country            0
# Description        3
# Target             8
# Target_class      17
# Year               0
# Date               6
# Unnamed: 13     1968
# dtype: int64

# %%
hack['Country'] = hack['Country'].fillna('US')
hack['Target_class'] = hack['Target_class'].fillna('Education')
hack['Target'] = hack['Target'].fillna('Nayana')
hack['Date'] = hack['Date'].fillna('12-06-2015')
hack['Unnamed: 0']=hack['Unnamed: 0'].fillna('The St. Louis Cardinals baseball franchise is ...	Houston ')
hack['Description']=hack['Description'].fillna('The St. Louis Cardinals baseball franchise is ...	Houston ')

# %%
hack.isnull().sum()
# Out:
# Unnamed: 0      0
# Attack          0
# Attack_class    0
# Author          0
# Country         0
# Description     0
# Target          0
# Target_class    0
# Year            0
# Date            0
# dtype: int64

# %%
hack[]

# %%
hack.isnull().sum()
# Out:
# Unnamed: 0         1
# Attack             0
# Attack_class       0
# Author             0
# Country            0
# Description        3
# Target             8
# Target_class      17
# Year               0
# Date               6
# Unnamed: 13     1968
# dtype: int64

# %%
hack
# Out:
#      Unnamed: 0                                         Attack  \
# 0             0                                      Anonymous
# 1             1                                      Anonymous
# 2             2                                        Malware
# 3             3                                Targeted Attack
# 4             4                                      Anonymous
# ...         ...                                            ...
# 1964       1961                                        Malware
# 1965       1962                                        Malware
# 1966       1963                                        Malware
# 1967       1964                                           DDoS
# 1968       1965  Account Hijacking (Business Email Compromise)
#
#          Attack_class                  Author Country  \
# 0         Cyber Crime               Anonymous      CA
# 1         Cyber Crime               Anonymous      IN
# 2         Cyber Crime               Anonymous      JP
# 3     Cyber Espionage               Anonymous      >1
# 4         Cyber Crime     St. Louis Cardinals      US
# ...               ...                     ...     ...
# 1964      Cyber Crime               Anonymous      KR
# 1965      Cyber Crime               Anonymous      UK
# 1966      Cyber Crime               Anonymous      UK
# 1967      Cyber Crime               Anonymous      HK
# 1968      Cyber Crime  Attackers from Nigeria      >1
#
#                                             Description  \
# 0     A server hack at Algonquin College in Ottawa l...
# 1     The salary accounts of more than 23 employees ...
# 2     The internal computer network of the state-run...
# 3     Researchers from Palo Alto Networks reveal the...
# 4     The St. Louis Cardinals baseball franchise is ...
# ...                                                 ...
# 1964  A South Korean Web-hosting service provider, N...
# 1965  University College London is hit by a ÂÃÃma...
# 1966   The Ulster University is also hit by Ransomware.
# 1967  Bitfinex, the worldÂÃÂªs largest US dollar-b...
# 1968  Kaspersky Lab reveal the details of a massive ...
#
#                                           Target                 Target_class  \
# 0                              Algonquin College                    Education
# 1                                    Infosys Ltd           Industry: Software
# 2     Japan Environmental Storage & Safety Corp.    Industry: waste treatment
# 3                                             >1  GovernmentÂÃÂ¬,\rMilitary
# 4                                 Houston Astros            Single Individual
# ...                                          ...                          ...
# 1964                                      Nayana              Industry: Telco
# 1965                   University College London                    Education
# 1966                           Ulster University                    Education
# 1967                                    Bitfinex      Cryptocurrency Exchange
# 1968                   Multiple Industrial Firms                 Industry: >1
#
#       Year        Date Unnamed: 13
# 0     2021  12-06-2015         NaN
# 1     2021  17-06-2015         NaN
# 2     2021  15-06-2015         NaN
# 3     2021  16-06-2015         NaN
# 4     2021  16-06-2015         NaN
# ...    ...         ...         ...
# 1964  2023  14-06-2017         NaN
# 1965  2023  15-06-2017         NaN
# 1966  2023  15-06-2017         NaN
# 1967  2023  15-06-2017         NaN
# 1968  2023  15-06-2017         NaN
#
# [1969 rows x 11 columns]

# %%
hack.to_csv('ndata.csv')

# %%
hack.groupby('Author').agg({'Attack':'count'}).sort_values('Attack', ascending = True).tail(20)[:-1].plot.barh(grid = False)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=8)
#plt.savefig("hacker.png",bbox_inches='tight')

# %%
hack['Attack']
# Out:
# 0                                           Anonymous
# 1                                           Anonymous
# 2                                             Malware
# 3                                     Targeted Attack
# 4                                           Anonymous
#                             ...
# 1964                                          Malware
# 1965                                          Malware
# 1966                                          Malware
# 1967                                             DDoS
# 1968    Account Hijacking (Business Email Compromise)
# Name: Attack, Length: 1969, dtype: object

# %%
g = hack.groupby(['Attack_class','Attack']).agg({'Target':'count'}).reset_index().sort_values('Target',ascending = False).head(50)
#sns.heatmap(g)
#
test = g.pivot("Attack","Attack_class","Target").fillna(0)

sns.heatmap(test)
plt.yticks(rotation=1)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=8)
#plt.savefig("heatmap.png",bbox_inches='tight')
# Out:
# <ipython-input-105-c402c3689f7f>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   test = g.pivot("Attack","Attack_class","Target").fillna(0)
# ) missing from current font.
#   fig.canvas.draw()
# ) missing from current font.
#   func(*args, **kwargs)
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
b = [i.split(' ')[0] for i in hack['Attack'].tolist() if type(i) != float]
b = [i.split(',')[0] for i in b if type(i) != float]
b = [i.split(',\r')[0] for i in b if type(i) != float]
b = [str(i).replace('?','') for i in b]

#b.groupby('Attack').agg({'Author':'count'}).reset_index().sort_values('Author', ascending = False)
pd.DataFrame.from_dict(dict(Counter(b)),orient='index').sort_values(0,ascending=True).tail(20)[:-1].plot.barh(grid=False)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=8)
#plt.savefig("top_attack_bar.png",bbox_inches='tight')

# %%
hack.groupby(['Author','Attack']).agg({'Target':'count'}).sort_values('Target',ascending = False)
#sns.heatmap(q)
# Out:
#                                                                        Target
# Author                                           Attack
# Anonymous                                        Anonymous                404
#                                                  Account Hijacking        174
#                                                  Malware                  138
#                                                  DDoS                     126
#                                                  Targeted Attack           87
# ...                                                                       ...
# Phineas Phisher AKA Hack Back! AKA @GammaGroupPR Anonymous                  0
# 24-07-2015                                       Industry: E-Commerce       0
# 18-07-2015                                       Law Enforcement            0
# 17-07-2015                                       Government                 0
# Blacksmith HackerÂÃÂªs Team                    Defacement                 0
#
# [691 rows x 1 columns]

# %%
hack = hack.replace(['cloudbleed'],['2017'])

# %%
hack['Country'] = hack['Country'].replace(['Cyber'],['US'])

# %%
hack.groupby('Author').agg(['count'])['Attack'].sort_values('count', ascending=False)
# Out:
#                  count
# Author
# Anonymous         1185
# OurMine             25
# Kapustkiy           12
# RussiaAnonymous     10
# Guccifer 2.0        10
# ...                ...
# DragonOK APT         1
# Dr.MwNs              1
# DetoxRansome         1
# Deletesec            1
# Ã¥ÃAnonymous        1
#
# [525 rows x 1 columns]

# %%
hack['Description'] = hack['Description'].astype(str)

# %%
descr = hack['Description'].tolist()
tf = [True if (re.findall('million|billion',i) != []) else False for i in descr]

# %%
n = [str(i).replace('Industry: ','') for i in hack['Target_class']]
n = [str(i).replace('Org: ','') for i in n]

# %%
hack['Target_class'] = n
hack
# Out:
#      Unnamed: 0                                         Attack  \
# 0             0                                      Anonymous
# 1             1                                      Anonymous
# 2             2                                        Malware
# 3             3                                Targeted Attack
# 4             4                                      Anonymous
# ...         ...                                            ...
# 1964       1961                                        Malware
# 1965       1962                                        Malware
# 1966       1963                                        Malware
# 1967       1964                                           DDoS
# 1968       1965  Account Hijacking (Business Email Compromise)
#
#          Attack_class                  Author Country  \
# 0         Cyber Crime               Anonymous      CA
# 1         Cyber Crime               Anonymous      IN
# 2         Cyber Crime               Anonymous      JP
# 3     Cyber Espionage               Anonymous      >1
# 4         Cyber Crime     St. Louis Cardinals      US
# ...               ...                     ...     ...
# 1964      Cyber Crime               Anonymous      KR
# 1965      Cyber Crime               Anonymous      UK
# 1966      Cyber Crime               Anonymous      UK
# 1967      Cyber Crime               Anonymous      HK
# 1968      Cyber Crime  Attackers from Nigeria      >1
#
#                                             Description  \
# 0     A server hack at Algonquin College in Ottawa l...
# 1     The salary accounts of more than 23 employees ...
# 2     The internal computer network of the state-run...
# 3     Researchers from Palo Alto Networks reveal the...
# 4     The St. Louis Cardinals baseball franchise is ...
# ...                                                 ...
# 1964  A South Korean Web-hosting service provider, N...
# 1965  University College London is hit by a ÂÃÃma...
# 1966   The Ulster University is also hit by Ransomware.
# 1967  Bitfinex, the worldÂÃÂªs largest US dollar-b...
# 1968  Kaspersky Lab reveal the details of a massive ...
#
#                                           Target                 Target_class  \
# 0                              Algonquin College                    Education
# 1                                    Infosys Ltd                     Software
# 2     Japan Environmental Storage & Safety Corp.              waste treatment
# 3                                             >1  GovernmentÂÃÂ¬,\rMilitary
# 4                                 Houston Astros            Single Individual
# ...                                          ...                          ...
# 1964                                      Nayana                        Telco
# 1965                   University College London                    Education
# 1966                           Ulster University                    Education
# 1967                                    Bitfinex      Cryptocurrency Exchange
# 1968                   Multiple Industrial Firms                           >1
#
#       Year        Date Unnamed: 13
# 0     2021  12-06-2015         NaN
# 1     2021  17-06-2015         NaN
# 2     2021  15-06-2015         NaN
# 3     2021  16-06-2015         NaN
# 4     2021  16-06-2015         NaN
# ...    ...         ...         ...
# 1964  2023  14-06-2017         NaN
# 1965  2023  15-06-2017         NaN
# 1966  2023  15-06-2017         NaN
# 1967  2023  15-06-2017         NaN
# 1968  2023  15-06-2017         NaN
#
# [1969 rows x 11 columns]

# %%
hack['Attack_class']=[str(i).replace(',\r','') for i in hack['Attack_class']]

# %%
hack['Attack_class']=hack['Attack_class'].replace(['CC','2015','CCCE','CW?','H','IN','Industry: Telco','JP','US'],['Cyber Crime','Cyber Crime','Cyber Espionage','Cyber War','Hacktivism','Cyber Crime','Cyber War','Hacktivism','Cyber Espionage'])

# %%
hack['Attack_class'].unique()
# Out:
# array(['Cyber Crime', 'Cyber Espionage', 'Hacktivism', 'Cyber War',
#        'CC,\r', 'H,\r', 'CC,\rCE'], dtype=object)

# %%
import matplotlib.pyplot as plt

# Calculate the count of each attack class
attack_counts = hack.groupby('Attack_class').agg({'Attack': 'count'})
attack_counts.plot.pie(subplots=True, explode=(0.03, 0), shadow=True)

# Set tick label size
plt.tick_params(labelsize=25)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-1a43eea1ff54> in <cell line: 5>()
#       3 # Calculate the count of each attack class
#       4 attack_counts = hack.groupby('Attack_class').agg({'Attack': 'count'})
# ----> 5 attack_counts.plot.pie(subplots=True, explode=(0.03, 0), shadow=True)
#       6
#       7 # Set tick label size
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in pie(self, **kwargs)
#    1610         ):
#    1611             raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1612         return self(kind="pie", **kwargs)
#    1613
#    1614     def scatter(self, x, y, s=None, c=None, **kwargs) -> PlotAccessor:
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     450         self._compute_plot_data()
#     451         self._setup_subplots()
# --> 452         self._make_plot()
#     453         self._add_table()
#     454         self._make_legend()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1839             else:
#    1840                 blabels = None
# -> 1841             results = ax.pie(y, labels=blabels, **kwds)
#    1842
#    1843             if kwds.get("autopct", None) is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3209             raise ValueError("'label' must be of length 'x'")
#    3210         if len(x) != len(explode):
# -> 3211             raise ValueError("'explode' must be of length 'x'")
#    3212         if colors is None:
#    3213             get_next_color = self._get_patches_for_fill.get_next_color
#
# ValueError: 'explode' must be of length 'x'

# %%
hack.groupby('Attack_class').agg({'Attack': 'count'}).plot.pie(subplots=True, explode=(0.3,0,0,0), shadow=True)
plt.tick_params(labelsize='25')
#plt.savefig("attack_class_pie.png",bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f4cfaa3f46b5> in <cell line: 1>()
# ----> 1 hack.groupby('Attack_class').agg({'Attack': 'count'}).plot.pie(subplots=True, explode=(0.3,0,0,0), shadow=True)
#       2 plt.tick_params(labelsize='25')
#       3 #plt.savefig("attack_class_pie.png",bbox_inches='tight')
#
# NameError: name 'hack' is not defined

# %%
hack.groupby('Target_class').agg({'Attack': 'count'}).sort_values('Attack', ascending = False) \
.head(20).plot.pie(subplots=True,shadow=True, counterclock = False,legend=None)
#mpl.rcParams['font.size'] = 20.0
#plt.tick_params(axis='both', which='major', labelsize=15)
#plt.tick_params(axis='both', which='minor', labelsize=8)
#plt.savefig("target_class.png",bbox_inches='tight')
# Out:
# array([<Axes: ylabel='Attack'>], dtype=object)

# %%
#[pd.to_datetime(i,format='%d/%m/%y') for i in hack['Date']]

# %%
hack.groupby(['Author','Attack']).agg({'Target':'count'}) \
.sort_values('Target',ascending = True).tail(25)[:-8].plot.barh(grid = False)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=8)
plt.savefig("author&attack_bar.png",bbox_inches='tight')

# %%
pd.set_option('display.max_rows', 300)

# %%
hack.groupby(['Author','Target_class','Country']).\
    agg({'Target':'count'}).reset_index().sort_values('Target',ascending = False)
# Out:
#                                                 Author        Target_class  \
# 212                                          Anonymous           Education
# 530                                          Anonymous  Single Individuals
# 301                                          Anonymous          Government
# 324                                          Anonymous          Healthcare
# 90                                           Anonymous                  >1
# ...                                                ...                 ...
# 9                                           18-07-2015                 nan
# 8                                           17-07-2015                 nan
# 729                      Blacksmith HackerÂÃÂªs Team                 nan
# 649                                          Anonymous                 nan
# 1066  Phineas Phisher AKA Hack Back! AKA @GammaGroupPR                 nan
#
#      Country  Target
# 212       US      68
# 530       >1      48
# 301       US      47
# 324       US      45
# 90        >1      35
# ...      ...     ...
# 9         US       0
# 8         US       0
# 729    PK,\r       0
# 649       CA       0
# 1066      US       0
#
# [1276 rows x 4 columns]

# %%
hack[hack['Author']=='Guccifer 2.0']['Description'].tolist()
# Out:
# ['Guccifer 2.0, the hacker who previously hacked the Democratic National Committee, leaks 21 internal documents on Hillary Clinton.',
#  'Guccifer 2.0 leaks 260 additional internal documents on Hillary Clinton.',
#  'Guccifer 2.0 releases 25 new documents.',
#  'Guccifer 2.0 leaks more documents from the computer networks of the US Democratic Party and exposes plans to spend more than $800,000 (Ã¥Â£614,660) on a Â\x89Ã\x9bÃ\x8fcounter-conventionÂ\x89Ã\x9bÂ\x9d in an attempt to hijack the upcoming Republican National Convention (RNC).',
#  'Guccifer 2.0 leaks more documents reportedly stolen from the computer networks of the Democratic National Committee (DNC), including opposition research, political donor lists and internal memos.',
#  'Guccifer 2.0, the hacker suspected of breaching the US Democratic National Committee releases another trove of internal documents containing financial documents, staff lists, donor records and memos marked as Â\x89Ã\x9bÃ·private and confidentialÂ\x89Ã\x9bÂª.',
#  'Guccifer 2.0 leaks a fresh batch of documents, memos and passwords, this time from the Democratic Congressional Campaign Committee (DCCC). They include a spreadsheet of congressional contactsÂ\x89Ã\x9bÂª phone numbers and email addresses, internal memos and what purports to be documents stolen from the computer of Nancy Pelosi, the highest-ranking Democrat in Congress.',
#  'Guccifer 2.0 releases a new cache of documents from the DCCC (Democratic Congressional Campaign Committee).',
#  'Guccifer 2.0 posts what the hacker claims are files stolen from the Clinton Foundation, but the foundation says the assertions are not true.',
#  "Guccifer 2.0 is back and leaks new fresh documents relating to the US political system (documents allegedly showing email conversations between DNC employees and Hillary Clinton's presidential campaign staff discussing Donald Trump's position on his tax returns)."]

# %%
authors = hack['Author'].tolist()

# %%
target = hack['Target'].tolist()

# %%
clas = hack['Target_class'].tolist()

# %%
country = hack['Country'].tolist()

# %%
a = [i.split(' ')[0] for i in country if type(i) != float]
a = [i.split(',')[0] for i in a if type(i) != float]
a = [i.split(',\r')[0] for i in a if type(i) != float]

# %%
print(Counter(a))
# Out:
# Counter({'US': 889, '>1': 197, 'UK': 114, 'IN': 64, 'CA': 49, 'RU': 39, 'AU': 35, 'JP': 33, 'KR': 25, 'DE': 24, 'IL': 22, 'IT': 21, 'CN': 21, 'FR': 21, 'GB': 21, 'UA': 19, 'TH': 18, 'BR': 16, 'SE': 14, 'ZA': 14, 'TR': 14, 'PK': 13, 'NL': 12, 'TW': 11, 'SA': 11, 'IE': 11, 'IR': 10, 'AZ': 9, 'HK': 9, 'CH': 8, 'PL': 7, 'VE': 7, 'PH': 7, 'INT': 7, 'BE': 6, 'MX': 6, 'NZ': 6, 'NO': 6, 'KE': 6, 'SG': 6, 'UAE': 5, 'BD': 5, 'DK': 5, 'AT': 5, 'CZ': 5, 'EU': 5, 'SY': 4, 'CY': 4, 'AM': 4, 'QA': 4, 'JO': 3, 'RO': 3, 'LK': 3, 'EC': 3, 'EG': 3, 'ES': 3, 'FI': 3, 'AE': 3, 'AF': 3, 'CC': 3, 'LU': 3, 'KY': 2, 'ID': 2, 'VN': 2, 'LB': 2, 'GR': 2, 'CR': 2, 'UG': 2, 'NG': 2, 'SK': 2, 'PA': 2, 'AL': 2, 'AR': 2, 'KW': 2, 'LT': 2, 'ME': 2, 'VU': 1, 'GE': 1, 'MY': 1, 'YU': 1, 'MA': 1, '>`1': 1, 'IQ': 1, 'IS': 1, 'BB': 1, 'OM': 1, '.TI': 1, 'KH': 1, 'CO': 1, 'RW': 1, 'H': 1, 'CL': 1, 'BO': 1, 'TZ': 1, 'GU': 1, 'AO': 1, 'DO': 1, 'FJ': 1, 'MM': 1, 'ZW': 1, 'KZ': 1, 'PY': 1, '>A': 1, 'LY': 1, 'HU': 1, 'BS': 1, 'SCOT': 1, 'KP': 1})

# %%
pd.DataFrame.from_dict(dict(Counter(a)),orient='index').sort_values(0,ascending=True).tail(20).plot.barh(grid=False)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=8)
#plt.savefig("country_bar.png",bbox_inches='tight')

# %%
description = hack['Description'].tolist()

# %%
target[:10]
# Out:
# ['Algonquin College',
#  'Infosys Ltd',
#  'Japan Environmental Storage & Safety Corp.',
#  '>1',
#  'Houston Astros',
#  'Bonnier Publications',
#  'EFnet',
#  'University of Baltimore affiliated website (bniajfi.org)',
#  'Canadian Governments Web Sites',
#  'digitalcostitution.com']

# %%
import nltk

# %%
import nltk
nltk.download('cmudict')
# Out:
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# True

# %%
word = nltk.corpus.cmudict.words()

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %%
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import word_tokenize,sent_tokenize
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in description:
    allwords_stemmed = tokenize_and_stem(i) #for each item in 'synopses', tokenize/stem
    totalvocab_stemmed.extend(allwords_stemmed) #extend the 'totalvocab_stemmed' list

    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)
print ('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
# Out:
# there are 50584 items in vocab_frame

# %%
print (vocab_frame.head())
# Out:
#                words
# a                  a
# server        server
# hack            hack
# at                at
# algonquin  algonquin

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#define vectorizer parameters
tfidf_vectorizer = TfidfVectorizer(max_df=0.5, max_features=200000,
                                 min_df=0.05, stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

# %time tfidf_matrix = tfidf_vectorizer.fit_transform(description) #fit the vectorizer to synopses

print(tfidf_matrix.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:409: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   warnings.warn(
# CPU times: user 2.6 s, sys: 37.3 ms, total: 2.64 s
# Wall time: 3.81 s
# (1969, 47)

# %%
terms = tfidf_vectorizer.get_feature_names_out()

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity (tfidf_matrix)

# %%
tfidf_matrix
# Out:
# <1969x47 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8301 stored elements in Compressed Sparse Row format>

# %%
from sklearn.cluster import KMeans

num_clusters = 12

km = KMeans(n_clusters=num_clusters)

# %time km.fit(tfidf_matrix)

clusters = km.labels_.tolist()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# CPU times: user 889 ms, sys: 20.1 ms, total: 909 ms
# Wall time: 1.16 s

# %%
import joblib

# %%
#uncomment the below to save your model
#since I've already run my model I am loading from the pickle

joblib.dump(km,  'doc_cluster.pkl')

km = joblib.load('doc_cluster.pkl')
clusters = km.labels_.tolist()

# %%
at = { 'target': target, 'author': authors, 'description': description, 'cluster': clusters,'class':clas }

clu = pd.DataFrame(at, index = [clusters] , columns = ['target', 'author', 'cluster','description','class'])

# %%
clu['cluster'].value_counts()
# Out:
# 9     284
# 3     209
# 5     195
# 8     176
# 2     172
# 10    160
# 1     153
# 7     150
# 11    140
# 6     122
# 4     104
# 0     104
# Name: cluster, dtype: int64

# %%
#### from __future__ import print_function

print("Top terms per cluster:")
print()
#sort cluster centers by proximity to centroid
order_centroids = km.cluster_centers_.argsort()[:, ::-1]

for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')

    for ind in order_centroids[i, :4]: #replace 6 with n words per cluster
        print(' %s' % vocab_frame.loc[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
    print() #add whitespace
    print() #add whitespace

#     print("Cluster %d titles:" % i, end='')
#     for title in clu.loc[i]['target'].values.tolist():
#         print(' %s,' % title, end='')
#     print() #add whitespace
#     print() #add whitespace

print()
print()
# Out:
# Top terms per cluster:
#
# Cluster 0 words: b'malware', b'used', b'reveal', b'target',
#
# Cluster 1 words: b'dumps', b'passwords', b'usernames', b'hack',
#
# Cluster 2 words: b'accounts', b'hack', b'hacker', b'million',
#
# Cluster 3 words: b'website', b'defaced', b'hacker', b'anonymous',
#
# Cluster 4 words: b'ddos', b'ddos', b'attacks', b'website',
#
# Cluster 5 words: b'reveal', b'target', b'campaign', b'new',
#
# Cluster 6 words: b'leaked', b'data', b'hack', b'hacker',
#
# Cluster 7 words: b'email', b'claims', b'hacker', b'passwords',
#
# Cluster 8 words: b'breach', b'data', b'customers', b'security',
#
# Cluster 9 words: b'data', b'compromised', b'hacker', b'access',
#
# Cluster 10 words: b'attacks', b'cyber', b'target', b'hack',
#
# Cluster 11 words: b'information', b'personal', b'access', b'compromised',

# %%
import os  # for os.path.basename

import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.manifold import MDS

MDS()

# convert two components as we're plotting points in a two-dimensional plane
# "precomputed" because we provide a distance matrix
# we will also specify `random_state` so the plot is reproducible.
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1)

pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

xs, ys = pos[:, 0], pos[:, 1]
print()
print()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-5a444caea307> in <cell line: 15>()
#      13 mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1)
#      14
# ---> 15 pos = mds.fit_transform(dist)  # shape (n_components, n_samples)
#      16
#      17 xs, ys = pos[:, 0], pos[:, 1]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_mds.py in fit_transform(self, X, y, init)
#     611             self.dissimilarity_matrix_ = euclidean_distances(X)
#     612
# --> 613         self.embedding_, self.stress_, self.n_iter_ = smacof(
#     614             self.dissimilarity_matrix_,
#     615             metric=self.metric,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_mds.py in smacof(dissimilarities, metric, n_components, init, n_init, n_jobs, max_iter, verbose, eps, random_state, return_n_iter, normalized_stress)
#     326     if effective_n_jobs(n_jobs) == 1:
#     327         for it in range(n_init):
# --> 328             pos, stress, n_iter_ = _smacof_single(
#     329                 dissimilarities,
#     330                 metric=metric,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_mds.py in _smacof_single(dissimilarities, metric, n_components, init, max_iter, verbose, eps, random_state, normalized_stress)
#     153         ratio = disparities / dis
#     154         B = -ratio
# --> 155         B[np.arange(len(B)), np.arange(len(B))] += ratio.sum(axis=1)
#     156         X = 1.0 / n_samples * np.dot(B, X)
#     157
#
# KeyboardInterrupt:

# %%
cluster_colors = {0: '#3db5aa', 1: '#d15545', 2: '#781835', 3: '#ffa21f', 4: '#86b313', 5: '#ff00c1', 6: '#686765', 7: '#9270ff', 8: '#560c64', 9: '#887136', 10:'#67beff', 11: '#f94848'}

#set up cluster names using a dict
cluster_names = {0: 'dumps, passwords, usernames, records : 145',

                 1: 'accounts, million, email, users : 185',

                 2: 'malware, reveal, used, researchers : 101',

                 3: 'website, anonymous, government, claims : 121',

                 4: 'campaign, target, reveal, new : 119',

                 5: 'breach, data, customers, security : 176',

                 6: 'defaced, website, officials, group : 112',

                 7: 'reveal, target, attacks, group : 221',

                 8: 'information, personal, access, compromised : 142',

                 9: 'ddos, attacks, website : 116',

                 10: 'data, leaked, customers, compromised : 143',

                 11: 'leaked, claims, database, anonymous : 383'}

# %%
# !pip install mpld3

# %%
import mpld3

# %%
class TopToolbar(mpld3.plugins.PluginBase):
    """Plugin for moving toolbar to top of figure"""

    JAVASCRIPT = """
    mpld3.register_plugin("toptoolbar", TopToolbar);
    TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
    TopToolbar.prototype.constructor = TopToolbar;
    function TopToolbar(fig, props){
        mpld3.Plugin.call(this, fig, props);
    };

    TopToolbar.prototype.draw = function(){
      // the toolbar svg doesn't exist
      // yet, so first draw it
      this.fig.toolbar.draw();

      // then change the y position to be
      // at the top of the figure
      this.fig.toolbar.toolbar.attr("x", 150);
      this.fig.toolbar.toolbar.attr("y", 400);

      // then remove the draw function,
      // so that it is not called again
      this.fig.toolbar.draw = function() {}
    }
    """
    def __init__(self):
        self.dict_ = {"type": "toptoolbar"}

# %%
#create data frame that has the result of the MDS plus the cluster numbers and titles
df = pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=target))

#group by cluster
groups = df.groupby('label')
number = groups.agg({'title':'count'})

#define custom css to format the font and to remove the axis labeling
css = """
text.mpld3-text, div.mpld3-tooltip {
  font-family:Arial, Helvetica, sans-serif;
}

g.mpld3-xaxis, g.mpld3-yaxis {
display: none; }

svg.mpld3-figure {
margin-left: -200px;}
"""

# Plot
fig, ax = plt.subplots(figsize=(24,12)) #set plot size
ax.margins(0.03) # Optional, just adds 5% padding to the autoscaling

#iterate through groups to layer the plot
#note that I use the cluster_name and cluster_color dicts with the 'name' lookup to return the appropriate color/label
for name, group in groups:
    points = ax.plot (group.x, group.y, marker='o', linestyle='', ms=10,
                     label=cluster_names[name], mec='none',
                     color=cluster_colors[name])
    ax.set_aspect('auto')
    labels = [i for i in group.title]

    #set tooltip using points, labels and the already defined 'css'
    tooltip = mpld3.plugins.PointHTMLTooltip(points[0], labels,
                                       voffset=20, hoffset=20, css=css)
    #connect tooltip to fig
    mpld3.plugins.connect(fig, tooltip, TopToolbar())

    #set tick marks as blank
    ax.axes.get_xaxis().set_ticks([])
    ax.axes.get_yaxis().set_ticks([])

    #set axis as blank
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)


ax.legend(numpoints=1,fontsize = 15) #show legend with only one dot


mpld3.display() #show the plot

#uncomment the below to export to html
html = mpld3.fig_to_html(fig)
Html_file= open("cluster2.html","w")
Html_file.write(html)
Html_file.close()

# %%
K = range(1,25)

KM = [KMeans(n_clusters=k).fit(tfidf_matrix) for k in K]


from scipy.spatial.distance import cdist, pdist

centroids = [k.cluster_centers_ for k in KM]
D_k = [cdist(tfidf_matrix.toarray(), cent,'euclidean') for cent in centroids]
cIdx = [np.argmin(D,axis=1) for D in D_k]
dist = [np.min(D,axis=1) for D in D_k]
avgWithinSS = [sum(d)/tfidf_matrix.shape[0] for d in dist]

# Total with-in sum of square
wcss = [sum(d**2) for d in dist]
tss = sum(pdist(tfidf_matrix.toarray())**2)/tfidf_matrix.shape[0]
bss = tss-wcss

kIdx = 10-1

# elbow curve
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111)
ax.plot(K, avgWithinSS, 'b*-')
ax.plot(K[kIdx], avgWithinSS[kIdx], marker='o', markersize=12,
markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')
plt.grid(True)
plt.xlabel('Number of clusters')
plt.ylabel('Average within-cluster sum of squares')
plt.title('Elbow for KMeans clustering')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(K, bss/tss*100, 'b*-')
plt.grid(True)
plt.xlabel('Number of clusters')
plt.ylabel('Percentage of variance explained')
plt.title('Elbow for KMeans clustering')

# %%
from sklearn.metrics import silhouette_score

s = []
for n_clusters in range(2,30):
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(tfidf_matrix)

    labels = kmeans.labels_
    centroids = kmeans.cluster_centers_

    s.append(silhouette_score(tfidf_matrix, labels))

plt.figure(figsize=(12,6))
plt.plot(s)
plt.ylabel("Silhouette")
plt.xlabel("k")
plt.title("Silhouette for K-means cell's behaviour")
sns.despine()

# %%
from sklearn.metrics import silhouette_score

# Assuming 'km' is your KMeans clustering model
# You can use km.labels_ as the cluster labels for your data points
# tfidf_matrix is your data matrix

# Calculate silhouette score
silhouette_avg = silhouette_score(tfidf_matrix, km.labels_)

print("Silhouette Score:", silhouette_avg)

# %%
groups.agg({'title':'count'}).sort_values('title',ascending=False)
